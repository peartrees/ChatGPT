# %% [markdown]
# <a href="https://colab.research.google.com/github/peartrees/ChatGPT/blob/main/LLM_Open_Calm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CyberAgentのLLM（open_calm）を試したノートブックです．
# ## 参考サイト
# - https://note.com/npaka/n/n2185b422a2f2

# %%
# !pip install transformers accelerate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 57.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.1/219.1 kB 21.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 24.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 80.2 MB/s eta 0:00:00
# ...

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

# モデルとトークナイザーの準備
model = AutoModelForCausalLM.from_pretrained(
    "cyberagent/open-calm-small", 
    device_map="auto", 
    torch_dtype=torch.float16
)
tokenizer = AutoTokenizer.from_pretrained("cyberagent/open-calm-7b")

# %%
# プロンプトの準備
prompt = "今日の夕飯は何にしたら良いですか？"

# 推論の実行
inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
with torch.no_grad():
    tokens = model.generate(
        **inputs,
        max_new_tokens=64,
        do_sample=True,
        temperature=0.7,
        pad_token_id=tokenizer.pad_token_id,
    )
    
output = tokenizer.decode(tokens[0], skip_special_tokens=True)
print(output)
# Out:
# 今日の夕飯は何にしたら良いですか?
# 私は今晩は、お昼は、ご飯に味噌汁と漬物、納豆、お漬物、トマト、キュウリ、ナス、キュウリ、にんにく、人参、玉ねぎ、キャベツ、ピーマン、にら、ネギに塩、こしょう、酢、おろしニンニク、胡椒、塩、
